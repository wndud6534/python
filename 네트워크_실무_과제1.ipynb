# %% [markdown]
# <a href="https://colab.research.google.com/github/wndud6534/python/blob/main/%EB%84%A4%ED%8A%B8%EC%9B%8C%ED%81%AC_%EC%8B%A4%EB%AC%B4_%EA%B3%BC%EC%A0%9C1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = 'https://apis.data.go.kr/1352000/ODMS_COVID_04/callCovid04Api'
para ={'serviceKey' : 'fmcZXR9Cxd57SVuEV9/vxZfBQuCECGLz/C68egjbd1T729I+RAqpBO2MIviqR8tTpbAqPOR3/+SmLgHnqkVUTg==', 'pageNo': '1', 'numOfRows': '500',  'apiType': 'xml', 'dataCd' : 'ASOS', 'std_day': '2023-01-01' }

res = requests.get(url, params=para)
print(res.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<response>\r\n <header>\r\n  <resultCode>00</resultCode>\r\n  <resultMsg>NORMAL SERVICE</resultMsg>\r\n </header>\r\n <body>\r\n  <items>\r\n   <item>\r\n    <deathCnt>6065</deathCnt>\r\n    <defCnt>5673241</defCnt>\r\n    <gubun>\xec\x84\x9c\xec\x9a\xb8</gubun>\r\n    <gubunCn>\xe9\xa6\x96\xe5\xb0\x94</gubunCn>\r\n    <gubunEn>Seoul</gubunEn>\r\n    <incDec>9990</incDec>\r\n    <isolClearCnt>0</isolClearCnt>\r\n    <isolIngCnt>0</isolIngCnt>\r\n    <localOccCnt>9990</localOccCnt>\r\n    <overFlowCnt>0</overFlowCnt>\r\n    <qurRate>59659</qurRate>\r\n    <stdDay>2023-01-01</stdDay>\r\n   </item>\r\n   <item>\r\n    <deathCnt>2692</deathCnt>\r\n    <defCnt>1721030</defCnt>\r\n    <gubun>\xeb\xb6\x80\xec\x82\xb0</gubun>\r\n    <gubunCn>\xe9\x87\x9c\xe5\xb1\xb1</gubunCn>\r\n    <gubunEn>Busan</gubunEn>\r\n    <incDec>4064</incDec>\r\n    <isolClearCnt>0</isolClearCnt>\r\n    <isolIngCnt>0</isolIngCnt>\r\n    <localOccCnt>4064</localOccCnt>\r\n
# ...

# %%
# 코랩 한글 깨짐 현상
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
#한글 처리1
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc('font',family='NanumGothic')
mpl.rcParams['axes.unicode_minus'] = False

# %%
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt

# XML 데이터 파싱
data = '''
<root>
    <item>
        <gubun>충남</gubun>
        <defCnt>1176252</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    <item>
        <gubun>전남</gubun>
        <defCnt>949367</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    <item>
        <gubun>광주</gubun>
        <defCnt>850624</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>세종</gubun>
        <defCnt>230763</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>대구</gubun>
        <defCnt>1271329</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>충북</gubun>
        <defCnt>913921</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경기</gubun>
        <defCnt>7884045</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>강원</gubun>
        <defCnt>861251</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>전북</gubun>
        <defCnt>974778</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>서울</gubun>
        <defCnt>5673241</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경남</gubun>
        <defCnt>1736948</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경북</gubun>
        <defCnt>1329501</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>대전</gubun>
        <defCnt>850275</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>제주</gubun>
        <defCnt>366548</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    
</root>
'''

root = ET.fromstring(data)

# 필요한 데이터 추출
locations = []
confirmed_cases = []
years = []
location_year_pairs = []

for item in root.findall('.//item'):
    location = item.find('gubun').text
    confirmed = int(item.find('defCnt').text)
    std_day = item.find('stdDay').text
    year = std_day.split('-')[0]  # Extract the year from the stdDay value
    locations.append(location)
    confirmed_cases.append(confirmed)
    years.append(year)
    location_year_pairs.append(f'{location} ({year})')  # Combine location and year

# 그래프 그리기 (선 그래프로 변경)
plt.plot(locations, confirmed_cases, marker='o')
plt.xlabel('지역')
plt.ylabel('확진자 수')
plt.title('지역별 코로나19 확진자 수 (2023년도별)')
plt.xticks(rotation=45)

# Y 축 숫자 단위 변경 (천 단위로 표시)
plt.ticklabel_format(style='plain', axis='y', useOffset=False, useMathText=True)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)

# 추가적인 그래프 모양 적용
plt.grid(True)  # 그리드 라인 추가
plt.tight_layout()  # 그래프 요소들이 겹치지 않도록 조정

plt.show()

# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import xml.etree.ElementTree as ET
import folium

# XML 데이터 파싱
data = '''
<root>
    <item>
        <gubun>충남</gubun>
        <defCnt>1176252</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    <item>
        <gubun>전남</gubun>
        <defCnt>949367</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    <item>
        <gubun>광주</gubun>
        <defCnt>850624</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>세종</gubun>
        <defCnt>230763</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>대구</gubun>
        <defCnt>1271329</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>충북</gubun>
        <defCnt>913921</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경기</gubun>
        <defCnt>7884045</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>강원</gubun>
        <defCnt>861251</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>전북</gubun>
        <defCnt>974778</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>서울</gubun>
        <defCnt>5673241</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경남</gubun>
        <defCnt>1736948</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경북</gubun>
        <defCnt>1329501</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>대전</gubun>
        <defCnt>850275</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>제주</gubun>
        <defCnt>366548</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    
</root>
'''

root = ET.fromstring(data)

# 지역 입력 받기
locations_input = input("지역 이름을 입력하세요 (여러 개의 지역은 쉼표로 구분): ").split(',')


# 필요한 데이터 추출
locations = []
confirmed_cases = []
years = []
location_year_pairs = []

for item in root.findall('.//item'):
    location = item.find('gubun').text
    confirmed = int(item.find('defCnt').text)
    std_day = item.find('stdDay').text
    year = std_day.split('-')[0]  # stdDay 값에서 연도 추출
    locations.append(location)
    confirmed_cases.append(confirmed)
    years.append(year)
    location_year_pairs.append(f'{location} ({year})')  # 지역과 연도 결합

# 대한민국 지도 생성
map_korea = folium.Map(location=[36.5, 127.5], zoom_start=7)


# 지도 출력
map_korea.save('map_korea.html')

# 지역별 확진자 수 원형 마커와 숫자로 표시
location_coordinates = {
    '충남': (36.6589, 126.6724),
    '전남': (34.8679, 126.9910),
    '광주': (35.1595, 126.8526),
    '세종': (36.4804, 127.2892),
    '대구': (35.8714, 128.6014),
    '충북': (36.6285, 127.9291),
    '경기': (37.4138, 127.5183),
    '강원': (37.8230, 128.1555),
    '전북': (35.7167, 127.1446),
    '서울': (37.5665, 126.9780),
    '경남': (35.4606, 128.2132),
    '경북': (36.4919, 128.8889),
    '대전': (36.3504, 127.3845),
    '제주': (33.4996, 126.5312)
    
}

for location_input in locations_input:
    for location, cases in zip(locations, confirmed_cases):
        if location == location_input.strip():  # 입력한 지역과 일치하는지 확인
            if location in location_coordinates:
                latitude, longitude = location_coordinates[location]
                folium.CircleMarker(
                    location=[latitude, longitude],
                    radius=cases / 500000,
                    color='red',
                    fill=True,
                    fill_color='red',
                    fill_opacity=0.6
                ).add_to(map_korea)

                folium.Marker(
                    location=[latitude, longitude],
                    icon=folium.DivIcon(html=f'<div style="font-size: 12px; font-weight: bold;">{cases}</div>')
            ).add_to(map_korea)


# 지도 출력
map_korea
# Out:
# 지역 이름을 입력하세요 (여러 개의 지역은 쉼표로 구분): 충남, 전남, 광주, 대구, 세종, 충북, 경기, 강원, 전북, 서울, 경남, 경북, 대전, 제주
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# 데이터 프레임 생성
df = pd.DataFrame({'지역': locations, '확진자 수': confirmed_cases, '연도': years})

# Excel 파일로 저장
df.to_excel('/content/output.xlsx', index=False)

# %%
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt

# XML 데이터 파싱
data = '''
<root>
    <item>
        <gubun>충남</gubun>
        <defCnt>1176252</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    <item>
        <gubun>전남</gubun>
        <defCnt>949367</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    <item>
        <gubun>광주</gubun>
        <defCnt>850624</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>세종</gubun>
        <defCnt>230763</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>대구</gubun>
        <defCnt>1271329</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
     <item>
        <gubun>충북</gubun>
        <defCnt>913921</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경기</gubun>
        <defCnt>7884045</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>강원</gubun>
        <defCnt>861251</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>전북</gubun>
        <defCnt>974778</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>서울</gubun>
        <defCnt>5673241</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경남</gubun>
        <defCnt>1736948</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>경북</gubun>
        <defCnt>1329501</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>대전</gubun>
        <defCnt>850275</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
      <item>
        <gubun>제주</gubun>
        <defCnt>366548</defCnt>
        <stdDay>2023-01-01</stdDay>
    </item>
    
</root>
'''

root = ET.fromstring(data)

# 사용자로부터 검색할 년도 입력받기
search_year = input("검색할 년도를 입력하세요 (YYYY): ")

# 필요한 데이터 추출
locations = []
confirmed_cases = []
years = []
location_year_pairs = []

for item in root.findall('.//item'):
    location = item.find('gubun').text
    confirmed = int(item.find('defCnt').text)
    std_day = item.find('stdDay').text
    year = std_day.split('-')[0]  # stdDay 값에서 연도 추출
    if year == search_year:  # 입력받은 년도와 일치하는 데이터만 추출
        locations.append(location)
        confirmed_cases.append(confirmed)
        years.append(year)
        location_year_pairs.append(f'{location} ({year})')  # 지역과 연도 결합

if not location_year_pairs:  # 검색 결과가 없는 경우
    print(f"{search_year}년에 해당하는 데이터가 없습니다.")
else:
    # 그래프 그리기 (선 그래프로 변경)
    plt.plot(location_year_pairs, confirmed_cases, marker='o')
    plt.xlabel('지역 (연도)')
    plt.ylabel('확진자 수')
    plt.title(f'지역별 코로나19 확진자 수 ({search_year}년도)')
    plt.xticks(rotation=45)

    # Y 축 숫자 단위 변경 (천 단위로 표시)
    plt.ticklabel_format(style='plain', axis='y', useOffset=False, useMathText=True)
    plt.gca().get_yaxis().get_major_formatter().set_scientific(False)

    # 추가적인 그래프 모양 적용
    plt.grid(True)  # 그리드 라인 추가
    plt.tight_layout()  # 그래프 요소들이 겹치지 않도록 조정

    plt.show()
# Out:
# 검색할 년도를 입력하세요 (YYYY): 2023
